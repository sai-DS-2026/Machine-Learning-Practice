# %%
#2. import necessary libraries
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.feature_selection import RFE,SelectFromModel
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Feature Selection techniques
# * Sklearn - SelectFromModel
# * Sklearn - RFE(Recursive Feature Elimination)

# %%
raw_data = load_breast_cancer()

# %%
breast_cancer_dataset = pd.DataFrame(data=raw_data.data,columns = raw_data.feature_names)
breast_cancer_dataset["Target"] = raw_data.target
breast_cancer_dataset
# Out:
#      mean radius  mean texture  mean perimeter  ...  worst symmetry  worst fractal dimension  Target
# 0          17.99         10.38          122.80  ...          0.4601                  0.11890       0
# 1          20.57         17.77          132.90  ...          0.2750                  0.08902       0
# 2          19.69         21.25          130.00  ...          0.3613                  0.08758       0
# 3          11.42         20.38           77.58  ...          0.6638                  0.17300       0
# 4          20.29         14.34          135.10  ...          0.2364                  0.07678       0
# ..           ...           ...             ...  ...             ...                      ...     ...
# 564        21.56         22.39          142.00  ...          0.2060                  0.07115       0
# 565        20.13         28.25          131.20  ...          0.2572                  0.06637       0
# ...

# %%
#3. Data Understanding
print(breast_cancer_dataset.shape)
print(breast_cancer_dataset.describe())
print(breast_cancer_dataset.dtypes)
print(breast_cancer_dataset.isna().sum())
# Out:
# (569, 31)
#        mean radius  mean texture  mean perimeter  ...  worst symmetry  worst fractal dimension      Target
# count   569.000000    569.000000      569.000000  ...      569.000000               569.000000  569.000000
# mean     14.127292     19.289649       91.969033  ...        0.290076                 0.083946    0.627417
# std       3.524049      4.301036       24.298981  ...        0.061867                 0.018061    0.483918
# min       6.981000      9.710000       43.790000  ...        0.156500                 0.055040    0.000000
# 25%      11.700000     16.170000       75.170000  ...        0.250400                 0.071460    0.000000
# 50%      13.370000     18.840000       86.240000  ...        0.282200                 0.080040    1.000000
# 75%      15.780000     21.800000      104.100000  ...        0.317900                 0.092080    1.000000
# max      28.110000     39.280000      188.500000  ...        0.663800                 0.207500    1.000000
#
# ...

# %%
#4. Model selection
X = breast_cancer_dataset.drop("Target",axis = 1)
y = breast_cancer_dataset["Target"]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=9,shuffle=True,stratify=y)
print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
rf_model_1 = RandomForestClassifier(max_depth=7,random_state=145)
rf_model_2 = RandomForestClassifier(max_depth=7,random_state=123)
rf_model_3 = RandomForestClassifier(max_depth=7,random_state=678)
rf_model_4 = RandomForestClassifier(random_state=678)
# Out:
# (455, 30) (455,)
# (114, 30) (114,)

# %%
#5. Model training || 6. Model Testing || 7. Model Evaluation
def training_testing_evaluating_model(model,training_data_x,training_data_y,testing_data_x,testing_data_y):
    model.fit(training_data_x,training_data_y) #training
    model_prediction = model.predict(testing_data_x) #testing

    #model evaluation
    print("Accuracy score",round(accuracy_score(model_prediction,testing_data_y),2))
    print("Precision score",round(precision_score(model_prediction,testing_data_y),2))
    print("Recall score",round(recall_score(model_prediction,testing_data_y),2))
    print("Confusion Matrix: \n",confusion_matrix(model_prediction,testing_data_y))

# %%
#using random forest model with max depth 7
training_testing_evaluating_model(rf_model_1,X_train,y_train,X_test,y_test)
# Out:
# Accuracy score 0.97
# Precision score 0.97
# Recall score 0.99
# Confusion Matrix:
#  [[41  2]
#  [ 1 70]]

# %%
#Using Select from model technique from feature selection
select_from_model_type = SelectFromModel(estimator=rf_model_2)
#if the model is un fitted with data, it throws value error
#ValueError: when `importance_getter=='auto'`, the underlying estimator RandomForestClassifier should have `coef_` or `feature_importances_` attribute. Either pass a fitted estimator to feature selector or call fit before calling transform.
select_from_model_type.fit(X_train,y_train)
select_from_model_type.get_support()
# true_list = [True for i in select_from_model_type.get_support() if i == True]
# print(len(true_list))
#X_train_cols = X_train.columns
select_model_type_X_train = select_from_model.transform(X_train)
select_model_type_X_test = select_from_model.transform(X_test)
#print(len(select_model_type_X_train.columns))
training_testing_evaluating_model(rf_model_2,select_model_type_X_train,y_train,select_model_type_X_test,y_test)
# Out:
# Accuracy score 0.97
# Precision score 0.97
# Recall score 0.99
# Confusion Matrix:
#  [[41  2]
#  [ 1 70]]

# %%
#using Recursive Feature Elimination

# %%
rfe = RFE(estimator=rf_model_3)
rfe.fit(X_train,y_train)
X_train_cols = X_train.columns
rfe_model_type_X_train = rfe.transform(X_train)
rfe_model_type_X_test = rfe.transform(X_test)

# %%
training_testing_evaluating_model(rf_model_3,rfe_model_type_X_train,y_train,rfe_model_type_X_test,y_test)
# Out:
# Accuracy score 0.97
# Precision score 0.99
# Recall score 0.97
# Confusion Matrix:
#  [[40  1]
#  [ 2 71]]

# %%
#using RFE to select important features for Gradient boosting and applying the features to Random Forest

# %%
rfe_gb = RFE(estimator=GradientBoostingClassifier(random_state=123))
rfe_gb.fit(X_train,y_train)
# Out:
# RFE(estimator=GradientBoostingClassifier(random_state=123))

# %%
selected_columns_gb = X_train.columns[rfe_gb.get_support()]
selected_columns_gb
# Out:
# Index(['mean texture', 'mean concave points', 'radius error', 'area error',
#        'smoothness error', 'compactness error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points'],
#       dtype='object')

# %%
X_train_rf_model_4 = X_train[selected_columns_gb]
X_test_rf_model_4 = X_test[selected_columns_gb]
print(X_train_rf_model_4.shape,X_test_rf_model_4.shape)
# Out:
# (455, 15) (114, 15)

# %%
training_testing_evaluating_model(rf_model_4,X_train_rf_model_4,y_train,X_test_rf_model_4,y_test)
# Out:
# Accuracy score 0.97
# Precision score 0.99
# Recall score 0.97
# Confusion Matrix:
#  [[40  1]
#  [ 2 71]]
