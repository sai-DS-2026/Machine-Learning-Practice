# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel,RFE
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix
import warnings
warnings.filterwarnings("ignore")

# %%
# 1. Data collection
credit_card_dataset = pd.read_csv("credit_card_clean.csv")
credit_card_dataset
# Out:
#           ID  LIMIT_BAL     SEX   EDUCATION MARRIAGE  AGE  PAY_1  PAY_2  \
# 0          1    20000.0  female  university  married   24      2      2
# 1          2   120000.0  female  university   single   26     -1      2
# 2          3    90000.0  female  university   single   34      0      0
# 3          4    50000.0  female  university  married   37      0      0
# 4          5    50000.0    male  university  married   57     -1      0
# ...      ...        ...     ...         ...      ...  ...    ...    ...
# 29995  29996   220000.0    male  highschool  married   39      0      0
# 29996  29997   150000.0    male  highschool   single   43     -1     -1
# 29997  29998    30000.0    male  university   single   37      4      3
# 29998  29999    80000.0    male  highschool  married   41      1     -1
# 29999  30000    50000.0    male  university  married   46      0      0
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
# %whos
# Out:
# Variable                 Type         Data/Info
# -----------------------------------------------
# LabelEncoder             type         <class 'sklearn.preproces<...>ing._label.LabelEncoder'>
# RFE                      ABCMeta      <class 'sklearn.feature_selection._rfe.RFE'>
# RandomForestClassifier   ABCMeta      <class 'sklearn.ensemble.<...>.RandomForestClassifier'>
# SelectFromModel          ABCMeta      <class 'sklearn.feature_s<...>m_model.SelectFromModel'>
# accuracy_score           function     <function accuracy_score at 0x0000012DC07D3250>
# confusion_matrix         function     <function confusion_matrix at 0x0000012DC07D3370>
# credit_card_dataset      DataFrame              ID  LIMIT_BAL  <...>[30000 rows x 25 columns]
# pd                       module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# plt                      module       <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# ...

# %%
# 2. Data understanding
print(credit_card_dataset.shape)
print("========================================================")
print(credit_card_dataset.isna().sum())
print("========================================================")
print(credit_card_dataset.dtypes)
print("==========================================================================================================")
print(credit_card_dataset.describe())
# Out:
# (30000, 25)
# ...
# ID           0
# LIMIT_BAL    0
# SEX          0
# EDUCATION    0
# MARRIAGE     0
# AGE          0
# PAY_1        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# DEFAULT      0
# dtype: int64
# ...
# ID             int64
# LIMIT_BAL    float64
# SEX           object
# EDUCATION     object
# MARRIAGE      object
# AGE            int64
# PAY_1          int64
# PAY_2          int64
# PAY_3          int64
# PAY_4          int64
# PAY_5          int64
# PAY_6          int64
# BILL_AMT1    float64
# BILL_AMT2    float64
# BILL_AMT3    float64
# BILL_AMT4    float64
# BILL_AMT5    float64
# BILL_AMT6    float64
# PAY_AMT1     float64
# PAY_AMT2     float64
# PAY_AMT3     float64
# PAY_AMT4     float64
# PAY_AMT5     float64
# ...

# %%
credit_card_dataset["EDUCATION"].unique()
# Out:
# array(['university', 'grad', 'highschool', 'other'], dtype=object)

# %%
# 3. Data Pre-Processing
del credit_card_dataset["ID"]
print(credit_card_dataset)
# Out:
#        LIMIT_BAL     SEX   EDUCATION MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 0        20000.0  female  university  married   24      2      2     -1
# 1       120000.0  female  university   single   26     -1      2      0
# 2        90000.0  female  university   single   34      0      0      0
# 3        50000.0  female  university  married   37      0      0      0
# 4        50000.0    male  university  married   57     -1      0     -1
# ...          ...     ...         ...      ...  ...    ...    ...    ...
# 29995   220000.0    male  highschool  married   39      0      0      0
# 29996   150000.0    male  highschool   single   43     -1     -1     -1
# 29997    30000.0    male  university   single   37      4      3      2
# 29998    80000.0    male  highschool  married   41      1     -1      0
# 29999    50000.0    male  university  married   46      0      0      0
#
#        PAY_4  PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
'''
SEX           object
EDUCATION     object
MARRIAGE      object
Need to change the datatypes
'''
le = LabelEncoder()
credit_card_dataset['SEX'] = le.fit_transform(credit_card_dataset['SEX'])
credit_card_dataset['MARRIAGE'] = le.fit_transform(credit_card_dataset['MARRIAGE'])
credit_card_dataset['EDUCATION'] = le.fit_transform(credit_card_dataset['EDUCATION'])
credit_card_dataset
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0        20000.0    0          3         0   24      2      2     -1     -1
# 1       120000.0    0          3         2   26     -1      2      0      0
# 2        90000.0    0          3         2   34      0      0      0      0
# 3        50000.0    0          3         0   37      0      0      0      0
# 4        50000.0    1          3         0   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995   220000.0    1          1         0   39      0      0      0      0
# 29996   150000.0    1          1         2   43     -1     -1     -1     -1
# 29997    30000.0    1          3         2   37      4      3      2     -1
# 29998    80000.0    1          1         0   41      1     -1      0      0
# 29999    50000.0    1          3         0   46      0      0      0      0
#
# ...

# %%
# 4. Model selection
X = credit_card_dataset.drop("DEFAULT",axis=1)
y = credit_card_dataset["DEFAULT"]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=345,stratify=y)

# %%
# 5. Model Training
RF_model = RandomForestClassifier()
RF_model_no_feature_engineering = RandomForestClassifier()
RF_model_no_feature_engineering.fit(X_train,y_train)
RF_model_for_rfe = RandomForestClassifier()

# %%
#Using select from model
select_from_model = SelectFromModel(estimator = RF_model)
select_from_model.fit(X_train,y_train)
select_from_model.get_support()
# Out:
# array([ True, False, False, False,  True,  True, False, False, False,
#        False, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True])

# %%
X_train[X_train.columns[select_from_model.get_support()]]
# Out:
#        LIMIT_BAL  AGE  PAY_1  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  \
# 18461   120000.0   24      0    89240.0    87970.0    82837.0    73297.0
# 9679     50000.0   41     -2    26948.0    16272.0     1000.0        0.0
# 1777     40000.0   43      0    41094.0    36554.0    37568.0    38314.0
# 12722   200000.0   34      0    73494.0    82253.0   179964.0      -36.0
# 17078    20000.0   24      0    13542.0    14852.0    15571.0    16584.0
# ...          ...  ...    ...        ...        ...        ...        ...
# 21817   140000.0   26      0    63119.0    64240.0    64992.0    52809.0
# 4115    180000.0   43     -1    36484.0    24049.0    89271.0     1946.0
# 16736   200000.0   31     -2     6926.0     1747.0      642.0        0.0
# 23161    50000.0   32      0    48237.0    49097.0    43763.0    37657.0
# 3607    200000.0   59      0    27119.0    28081.0    30299.0    29516.0
#
#        BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT6
# ...

# %%
#6. Model Training || 7. Model Testing
def runRandomForestClassifier(X_train,X_test,y_train,y_test):
    rf_model = RandomForestClassifier(max_depth=7,random_state=123)
    rf_model.fit(X_train,y_train)
    
    y_pred = rf_model.predict(X_test)
    
    print("Accuracy Score:",round(accuracy_score(y_test,y_pred),4))
    print("Precision Score:",round(precision_score(y_test,y_pred),4))
    print("Recall Score",round(recall_score(y_test,y_pred),4))
    print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))

# = train_test_model(RF_model,X_train,X_test,y_train,y_test)
#y_pred_0 = train_test_model(RF_model_no_feature_engineering,X_train,X_test,y_train,y_test)

# %%
def evaluation(prediction,actual_results):
    print("Accuracy score",round(accuracy_score(prediction,actual_results),2))
    print("Precision score",round(precision_score(prediction,actual_results),2))
    print("Recall score",round(recall_score(prediction,actual_results),2))
    print("Confusion Matrix: \n",confusion_matrix(prediction,actual_results))

evaluation(y_pred,y_test)
evaluation(y_pred_0,y_test)
# Out:
# Accuracy score 0.82
# Precision score 0.37
# Recall score 0.65
# Confusion Matrix:
#  [[4406  830]
#  [ 267  497]]
# Accuracy score 0.82
# Precision score 0.38
# Recall score 0.64
# Confusion Matrix:
#  [[4383  819]
#  [ 290  508]]

# %%
#using RFE
rfe_model = RFE(estimator=RF_model_for_rfe)
rfe_model.fit(X_train,y_train)
# Out:
# RFE(estimator=RandomForestClassifier())

# %%
X_train[X_train.columns[rfe_model.get_support()]]
# Out:
#        LIMIT_BAL  AGE  PAY_1  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  \
# 18461   120000.0   24      0    89240.0    87970.0    82837.0    73297.0
# 9679     50000.0   41     -2    26948.0    16272.0     1000.0        0.0
# 1777     40000.0   43      0    41094.0    36554.0    37568.0    38314.0
# 12722   200000.0   34      0    73494.0    82253.0   179964.0      -36.0
# 17078    20000.0   24      0    13542.0    14852.0    15571.0    16584.0
# ...          ...  ...    ...        ...        ...        ...        ...
# 21817   140000.0   26      0    63119.0    64240.0    64992.0    52809.0
# 4115    180000.0   43     -1    36484.0    24049.0    89271.0     1946.0
# 16736   200000.0   31     -2     6926.0     1747.0      642.0        0.0
# 23161    50000.0   32      0    48237.0    49097.0    43763.0    37657.0
# 3607    200000.0   59      0    27119.0    28081.0    30299.0    29516.0
#
#        BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2
# ...

# %%
new_X_train = rfe_model.transform(X_train)
new_X_test = rfe_model.transform(X_test)

# %%
RF_model_for_rfe.fit(new_X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = RF_model_for_rfe.predict(new_X_test)

# %%
    print("Accuracy Score:",round(accuracy_score(y_test,y_pred),4))
    print("Precision Score:",round(precision_score(y_test,y_pred),4))
    print("Recall Score",round(recall_score(y_test,y_pred),4))
    print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
# Out:
# Accuracy Score: 0.8188
# Precision Score: 0.6579
# Recall Score 0.3768
# Confusion Matrix:
#  [[4413  260]
#  [ 827  500]]
