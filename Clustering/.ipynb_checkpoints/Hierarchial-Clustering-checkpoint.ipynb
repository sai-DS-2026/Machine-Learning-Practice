# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from matplotlib import pyplot as plt
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
#2. Data collection
colleges_dataframe = pd.read_csv(r'college_list.csv')

# %%
#3. Data Understanding
print(colleges_dataframe.shape)
print("++++++++++++++++++++++++++++")
print(colleges_dataframe.dtypes)
print("++++++++++++++++++++++++++++")
print(colleges_dataframe.isna().sum())
print("++++++++++++++++++++++++++++")
colleges_dataframe.describe()
# Out:
# (500, 6)
# ++++++++++++++++++++++++++++
# College_Name              object
# Student_Faculty_Ratio      int64
# Annual_Fees_INR            int64
# Placement_Percentage       int64
# Average_Package_LPA      float64
# Infrastructure_Score       int64
# dtype: object
# ++++++++++++++++++++++++++++
# College_Name             0
# Student_Faculty_Ratio    0
# Annual_Fees_INR          0
# Placement_Percentage     0
# Average_Package_LPA      0
# Infrastructure_Score     0
# dtype: int64
# ++++++++++++++++++++++++++++
#        Student_Faculty_Ratio  Annual_Fees_INR  Placement_Percentage  \
# count             500.000000       500.000000            500.000000
# mean               18.084000    138763.710000             69.000000
# std                 6.683283     63928.678815             17.193465
# min                 8.000000     30404.000000             40.000000
# 25%                12.000000     82610.500000             53.750000
# 50%                18.000000    140290.500000             69.000000
# 75%                24.000000    193422.000000             84.000000
# max                29.000000    249930.000000             99.000000
#
#        Average_Package_LPA  Infrastructure_Score
# count           500.000000             500.00000
# mean              6.991720               5.97600
# std               2.917991               2.00486
# min               2.000000               3.00000
# 25%               4.472500               4.00000
# 50%               7.155000               6.00000
# 75%               9.432500               8.00000
# max              11.990000               9.00000

# %%
#4. Data Preprocessing
X = colleges_dataframe.drop("College_Name",axis = 1)
X
# Out:
#      Student_Faculty_Ratio  Annual_Fees_INR  Placement_Percentage  \
# 0                       14           113042                    59
# 1                       27           115999                    67
# 2                       22            47955                    50
# 3                       18            67841                    43
# 4                       15           100640                    54
# ..                     ...              ...                   ...
# 495                     17           106323                    56
# 496                     12            39111                    76
# 497                     16           199182                    64
# 498                     10            46389                    77
# 499                     24           152177                    97
#
#      Average_Package_LPA  Infrastructure_Score
# 0                   9.20                     8
# 1                   3.07                     7
# 2                   3.40                     9
# 3                   4.64                     8
# 4                   4.66                     9
# ..                   ...                   ...
# 495                 9.33                     5
# 496                 3.62                     7
# 497                 3.88                     3
# 498                 9.31                     6
# 499                 3.56                     8
#
# [500 rows x 5 columns]

# %%
#standardization
standard_scaler = StandardScaler()
scaled_X = standard_scaler.fit_transform(X)
scaled_X
# Out:
# array([[-0.61168888, -0.40275305, -0.58219883,  0.75753895,  1.01055795],
#        [ 1.33541089, -0.35645205, -0.11643977, -1.34532562,  0.51127043],
#        [ 0.58652636, -1.42189166, -1.10617777, -1.23212084,  1.50984548],
#        ...,
#        [-0.31213507,  0.94603549, -0.29109941, -1.06745934, -1.48587968],
#        [-1.21079651, -1.44641224,  0.46575906,  0.79527388,  0.0119829 ],
#        [ 0.88608017,  0.21002661,  1.63015672, -1.17723367,  1.01055795]],
#       shape=(500, 5))
